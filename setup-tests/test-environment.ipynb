# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf
import requests
from datetime import datetime

print("✅ Tous les packages importés avec succès !")
print(f"Pandas version: {pd.__version__}")
print(f"Date du test: {datetime.now()}")
# Out:
# ✅ Tous les packages importés avec succès !
# Pandas version: 2.2.3
# Date du test: 2025-09-28 15:51:14.706471

# %%
print("📈 Test récupération données Bitcoin...")
data = yf.download("BTC-USD", start="2023-01-01", end="2024-01-01")
print(f"Données récupérées: {len(data)} jours")
print("\n5 premiers prix:")
print(data['Close'].head())
# Out:
# C:\Users\olivi\AppData\Local\Temp\ipykernel_23724\1261093681.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download("BTC-USD", start="2023-01-01", end="2024-01-01")
# [*********************100%***********************]  1 of 1 completed
# 📈 Test récupération données Bitcoin...
# Données récupérées: 365 jours
#
# 5 premiers prix:
# Ticker           BTC-USD
# Date
# 2023-01-01  16625.080078
# 2023-01-02  16688.470703
# 2023-01-03  16679.857422
# 2023-01-04  16863.238281
# 2023-01-05  16836.736328

# %%
# Cellule 3 : Test graphique
print("📊 Création graphique...")
plt.figure(figsize=(12, 6))
data['Close'].plot(title="Bitcoin Price Test", color='orange')
plt.ylabel("Prix (USD)")
plt.xlabel("Date")
plt.grid(True, alpha=0.3)
plt.show()
print("✅ Graphique créé avec succès !")
# Out:
# 📊 Création graphique...
# ✅ Graphique créé avec succès !

# %%
print("🔗 Test API CoinGecko...")
url = "https://api.coingecko.com/api/v3/ping"
response = requests.get(url)

if response.status_code == 200:
    print("✅ API CoinGecko accessible !")
    print(f"Réponse: {response.json()}")
else:
    print("❌ Problème API")
# Out:
# 🔗 Test API CoinGecko...
# ✅ API CoinGecko accessible !
# Réponse: {'gecko_says': '(V3) To the Moon!'}
